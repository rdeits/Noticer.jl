# %%
]activate .
# Out:
#   Activating project at `~/Projects/Noticer.jl`

# %%
using Noticer
using Test

# %%
features = all_features();
model = Model(features);

# %%
Report(evaluate(model, split("""
            mumble
            moomy
            hamm
""")))
# Out:
# Report(Noticer.FeatureResult[FeatureResult(
# 	Number of occurrences of 'm', p=1.5e-06,
# 	obs: __▇_,
# 	exp: ▇▁__), FeatureResult(
# 	Number of unique letters, p=0.019,
# 	obs: ___▇_▄_,
# 	exp: ___▁▄▇▄), FeatureResult(
# 	Has a transdeletion with letter 'm', p=0.025,
# 	obs: ▄▇,
# 	exp: ▇▁), FeatureResult(
# 	Character at index 4, p=0.035,
# 	obs: __▄__________▇_____________,
# 	exp: _▄▁▂▂▇▁▂▁▅_▂▃▂▃▃▂_▃▄▄▂▁▁_▁▁), FeatureResult(
# 	Number of repeated letters, p=0.037,
# 	obs: _▇▄_,
# 	exp: ▇▅▁_), FeatureResult(
# 	Number of letters repeated at least 2 times, p=0.037,
# 	obs: _▇▄_,
# 	exp: ▇▅▁_), FeatureResult(
# 	Number of repeated consonants, p=0.047,
# 	obs: _▇__,
# 	exp: ▇▂__), FeatureResult(
# 	Character at index 2 from the end, p=0.071,
# 	obs: ____________▄▇_____________,
# 	exp: _▃_▁▁▇_▁▁▂_▁▂▁▂▂▁_▂▁▂▁___▁_), FeatureResult(
# 	Number of double letters, p=0.079,
# 	obs: ▄▇_,
# 	exp: ▇▁_), FeatureResult(
# 	Number of occurrences of 'o', p=0.14,
# 	obs: ▇_▄__,
# ...
